# %% [markdown]
# <a href="https://colab.research.google.com/github/EA-Digifolk/MEI_MTC_Parser/blob/main/Example-Usage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
#@title Install Musescore and Libs
# !apt-get update -q && apt-get install musescore lilypond -q
# %env QT_QPA_PLATFORM=offscreen

import music21

env = music21.environment.Environment()
env['lilypondPath'] = '/usr/local/bin/lilypond'

env['pdfPath'] = '/usr/bin/musescore'
env['graphicsPath'] = '/usr/bin/musescore'

env['musicxmlPath'] = '/usr/bin/musescore'
env['musescoreDirectPNGPath'] = '/usr/bin/musescore'
env['autoDownload'] = 'allow'

env['warnings'] = 0

# !pip install xlrd -q
# !pip install music21 -q
# !pip install syvmo -q
# !pip install mir_eval
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,192 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,532 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# # Get Dataset and Parser

# %%
#@title Get IFolk
# %cd /content

import os
if os.path.exists('iFolk'):
  # !git -C iFolk pull
else:
  # !git clone https://github.com/NadiaCarvalho/iFolk.git
# Out:
# /content
# Cloning into 'iFolk'...
# remote: Enumerating objects: 6940, done.
# remote: Counting objects: 100% (848/848), done.
# remote: Compressing objects: 100% (272/272), done.
# remote: Total 6940 (delta 657), reused 727 (delta 576), pack-reused 6092 (from 1)
# Receiving objects: 100% (6940/6940), 13.44 MiB | 16.23 MiB/s, done.
# Resolving deltas: 100% (6179/6179), done.

# %%
#@title Get Parser
# %cd /content

import os
if os.path.exists('MEI_MTC_Parser'):
  # !git -C MEI_MTC_Parser pull
else:
  # !git clone https://github.com/EA-Digifolk/MEI_MTC_Parser.git


# !pip install -r MEI_MTC_Parser/requirements.txt -q

import sys
if not '/content/MEI_MTC_Parser' in sys.path:
  sys.path.append('/content/MEI_MTC_Parser')
# Out:
# /content
# Cloning into 'MEI_MTC_Parser'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 54 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 25.45 KiB | 8.48 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.8/22.8 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 23.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.3/407.3 kB 13.4 MB/s eta 0:00:00

# %% [markdown]
# # How to Use Parser

# %%
# %cd '/content'

from mei_mtc_parser import MeiParser

parser = MeiParser()
song = parser.parse_mei('iFolk/Mexican/MX-1951-00-VM-00001.mei')

# Para ver a partitura
parser.mtc_extractor.music_stream.show()

# Para extrair algumas features para um pandas PD (exemplo)
df = pd.DataFrame().from_dict(song['v1']['features'])
df['offsets'] = df['offsets'].apply(lambda x: float(x))
df['duration_frac'] = df['duration_frac'].apply(lambda x: Fraction(x) if x is not None else 0)
df['restduration_frac'] = df['restduration_frac'].apply(lambda x: Fraction(x) if x is not None else 0)

# Lyrics
song['v1']['features']['lyrics']
#list of tuples per note (number of verse, syllable, "begin, middle or end of word or syllable corresponds to single word")
